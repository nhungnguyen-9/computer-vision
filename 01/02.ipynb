# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
dir = 'D:/Uni/Python/img/1'
print(dir)
# Out:
# D:/Uni/Python/img/1

# %%
imgs = get_image_list(dir)

# %%
# show all images
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (735, 734)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=735x734>
# (1080, 1080)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1080>
# (565, 543)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=565x543>
# (735, 734)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=735x734>
# (735, 734)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=735x734>
