# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'D:/Uni/Python/img/1/1.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=735x734>

# %%
#rotate
rotated_img = img.rotate(180)
display(rotated_img)
# Out:
# <PIL.Image.Image image mode=RGB size=735x734>

# %%
# transpose img
transposed_img = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=734x735>
